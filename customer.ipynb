# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\mohan rao papolu\OneDrive\chinni\Datasets\customer_purchase_data.csv")

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data.tail()
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 29   48       1  138727.303185                  9                0
# 30   52       1   42589.007108                  1                1
# 31   63       0   80023.098696                 11                2
# 36   53       1   93069.463272                 12                3
# 38   66       0  124009.225931                  7                4
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 29           13.715259               0                 2               0
# 30            3.626033               1                 5               0
# 31           44.969248               0                 0               0
# 36           44.393225               1                 0               1
# 38           52.244617               0                 0               0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.shape
# Out:
# (1500, 9)

# %%
data.isna().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
data[['AnnualIncome','Age','TimeSpentOnWebsite']].head()
# Out:
#     AnnualIncome  Age  TimeSpentOnWebsite
# 0   66120.267939   40           30.568601
# 1   23579.773583   20           38.240097
# 2  127821.306432   27           31.633212
# 3  137798.623120   24           46.167059
# 4   99300.964220   31           19.823592

# %%
data.groupby(by='Gender').count()
# Out:
#         Age  AnnualIncome  NumberOfPurchases  ProductCategory  \
# Gender
# 0       743           743                743              743
# 1       757           757                757              757
#
#         TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# Gender
# 0                      743             743               743             743
# 1                      757             757               757             757

# %%
data.duplicated().sum()
# Out:
# 112

# %%
data1=data
print(data1)
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data1.drop_duplicates(inplace=True)

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data.groupby(by='Age').count()
# Out:
#      Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# Age
# 18       33            33                 33               33
# 19       31            31                 31               31
# 20       28            28                 28               28
# 21       23            23                 23               23
# 22       33            33                 33               33
# 23       25            25                 25               25
# 24       22            22                 22               22
# 25       32            32                 32               32
# 26       24            24                 24               24
# 27       22            22                 22               22
# 28       26            26                 26               26
# 29       26            26                 26               26
# 30       22            22                 22               22
# 31       27            27                 27               27
# ...

# %%
df2=data['NumberOfPurchases'].value_counts()
print(df2)
# Out:
# NumberOfPurchases
# 14    83
# 12    81
# 16    79
# 15    78
# 19    77
# 10    77
# 11    73
# 7     67
# 13    67
# 9     67
# 3     65
# 20    65
# 18    64
# 5     61
# 6     60
# 4     58
# 17    58
# 2     55
# 1     55
# 8     50
# 0     48
# Name: count, dtype: int64

# %%
df3=data['TimeSpentOnWebsite'].value_counts()
print(df3)
# Out:
# TimeSpentOnWebsite
# 30.568601    1
# 29.718312    1
# 7.814846     1
# 16.882195    1
# 24.127885    1
#             ..
# 54.212665    1
# 57.310944    1
# 58.835411    1
# 2.277088     1
# 25.348017    1
# Name: count, Length: 1388, dtype: int64

# %%
df4=data['ProductCategory'].value_counts()
print(df4)
# Out:
# ProductCategory
# 1    306
# 4    289
# 3    270
# 0    269
# 2    254
# Name: count, dtype: int64

# %%
df5=data['LoyaltyProgram'].value_counts()
print(df5)
# Out:
# LoyaltyProgram
# 0    925
# 1    463
# Name: count, dtype: int64

# %%
df6=data['DiscountsAvailed'].value_counts()
print(df6)
# Out:
# DiscountsAvailed
# 4    249
# 5    247
# 3    246
# 1    219
# 2    217
# 0    210
# Name: count, dtype: int64

# %%
df7=data['PurchaseStatus'].value_counts()
print(df7)
# Out:
# PurchaseStatus
# 0    740
# 1    648
# Name: count, dtype: int64

# %%
df8=data['Gender'].value_counts()
print(df8)
# Out:
# Gender
# 1    696
# 0    692
# Name: count, dtype: int64

# %%
data.plot()
# Out:
# <Axes: >

# %%
data['Age'].head(45).plot()
# Out:
# <Axes: >

# %%
topdiscountcustomers = data.nlargest(9, 'DiscountsAvailed')
print(topdiscountcustomers)
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0    40       1   66120.267939                  8                0
# 1    20       1   23579.773583                  4                2
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
# 12   54       0  114467.228969                  9                2
# 20   59       0   92768.238873                  3                2
# 21   19       0  116945.391755                 17                3
# 26   67       1  102252.544237                 14                1
# 28   67       1   23792.069274                 15                4
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0            30.568601               0                 5               1
# 1            38.240097               0                 5               0
# 9            38.572466               0                 5               1
# ...

# %%
product_purchases = data.groupby('ProductCategory')['PurchaseStatus'].sum().sort_values(ascending=False)
print(product_purchases)
# Out:
# ProductCategory
# 1    149
# 3    133
# 4    133
# 0    117
# 2    116
# Name: PurchaseStatus, dtype: int64

# %%
sns.barplot(data = data, x='NumberOfPurchases', y='AnnualIncome')
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='AnnualIncome'>

# %%
sns.barplot(data = data, x='ProductCategory', y='TimeSpentOnWebsite')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='TimeSpentOnWebsite'>

# %%
sns.barplot(data = data, x='LoyaltyProgram', y='DiscountsAvailed')
# Out:
# <Axes: xlabel='LoyaltyProgram', ylabel='DiscountsAvailed'>

# %%
product_purchases = data.groupby('ProductCategory')['PurchaseStatus'].sum().sort_values(ascending=False)
plt.figure(figsize=(3,4))
plt.pie(product_purchases, labels=product_purchases.index, autopct='%1.1f%%')
plt.title('product purchases by category')
plt.axis('equal')
plt.show()

# %%
Discounts = data.groupby('Age')['DiscountsAvailed'].sum().sort_values(ascending=False)
print(Discounts)
# Out:
# Age
# 50    123
# 68    111
# 66    110
# 19     98
# 18     97
# 47     96
# 64     94
# 43     94
# 39     91
# 22     88
# 52     85
# 61     84
# 70     83
# 29     83
# 25     82
# 62     80
# 45     80
# 40     79
# 49     78
# 54     76
# 56     75
# 38     75
# 69     74
# 57     73
# 37     72
# 55     71
# 34     70
# 41     68
# 42     68
# 23     67
# 44     67
# 20     67
# 46     66
# 21     63
# 53     62
# 36     62
# 65     61
# 27     61
# 67     61
# 31     60
# 32     60
# 35     59
# 51     59
# 30     58
# 60     56
# 28     56
# 33     55
# 48     54
# 26     53
# 24     50
# 58     46
# 59     37
# 63     35
# Name: DiscountsAvailed, dtype: int64

# %%
age_bins = [0, 30, 60, 100]
age_labels = ['Young (0-30)', 'Middle-aged (31-60)', 'Senior (61+)']
data['AgeCategory'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)
age_discount_distribution = data.groupby('AgeCategory')['DiscountsAvailed'].sum().sort_values(ascending=False)
print("Total Discounts Availed by Age Category:")
print(age_discount_distribution)
# Out:
# Total Discounts Availed by Age Category:
# AgeCategory
# Middle-aged (31-60)    2117
# Young (0-30)            923
# Senior (61+)            793
# Name: DiscountsAvailed, dtype: int64

# %%
df=data[data.index.isin(range(0,18))]
df1=df.loc[df['NumberOfPurchases']>=5]
sns.barplot(data = df1, y= 'NumberOfPurchases', x= 'ProductCategory')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='NumberOfPurchases'>

# %%
age_over_50 = data[data['Age'] > 50]
plt.figure(figsize=(4, 5))
plt.hist(age_over_50['NumberOfPurchases'], bins=10,  edgecolor='black')
plt.title('Histogram of Number of Purchases for Customers Aged Over 50')
plt.xlabel('Number of Purchases')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
product_purchases = data.groupby('ProductCategory')['PurchaseStatus'].sum().sort_values(ascending=False)
print(product_purchases)
# Out:
# ProductCategory
# 1    149
# 3    133
# 4    133
# 0    117
# 2    116
# Name: PurchaseStatus, dtype: int64

# %%
x = data.nlargest(10,'TimeSpentOnWebsite')
x
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 616    29       1   58153.547017                 16                2
# 209    42       0   42778.830374                 17                3
# 689    18       1   87934.957914                  6                0
# 1394   45       0  149200.290557                  7                3
# 172    53       1   21575.700704                 10                4
# 235    38       1   30519.506797                  4                4
# 1285   50       0   49396.293062                 14                4
# 389    58       0  104626.550730                  1                1
# 748    22       1  106640.196178                 10                4
# 571    21       1   28796.887047                 14                2
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 616            59.991105               1                 3               1
# ...

# %%
df=data[data.index.isin(range(9,45))]
df1=df.loc[df['AnnualIncome']>=25000.00]
sns.lineplot(data = df1, x= 'ProductCategory', y= 'NumberOfPurchases')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='NumberOfPurchases'>

# %%
data1=data[(data['Age']>=45)&(data['NumberOfPurchases']<9)]
sns.lineplot(x='Age', y='NumberOfPurchases', data=data1)
# Out:
# <Axes: xlabel='Age', ylabel='NumberOfPurchases'>

# %%
sns.countplot(y='DiscountsAvailed', data=data,edgecolor='black')
# Out:
# <Axes: xlabel='count', ylabel='DiscountsAvailed'>

# %%
data1=data[data.index.isin(range(9,45))]
sns.countplot(y='ProductCategory', data=data1)
# Out:
# <Axes: xlabel='count', ylabel='ProductCategory'>

# %%
sns.stripplot(x='NumberOfPurchases', y='Age', data=data1)
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='Age'>

# %%
x=data.Age.max()
print(x)
y=data.Age.min()
print(y)
# Out:
# 70
# 18

# %%
data1=data[data['Age']>45]
sns.stripplot(y='Age', x='LoyaltyProgram', data=data1)
# Out:
# <Axes: xlabel='LoyaltyProgram', ylabel='Age'>

# %%
data1= data.groupby('DiscountsAvailed')['NumberOfPurchases'].sum().sort_values(ascending=False)
plt.figure(figsize=(3,4))
plt.pie(data1, labels=data1.index, autopct='%1.1f%%')
plt.title('Discounts availed by number of purchases')
plt.axis('equal')
plt.show()

# %%
sns.pairplot(data[['ProductCategory','DiscountsAvailed','LoyaltyProgram','PurchaseStatus']])

# %%
data1=data
sns.jointplot(data=data1, x="ProductCategory", y="DiscountsAvailed")

# %%
dt = sns.violinplot(x=data['DiscountsAvailed'])

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=correlation, cmap="magma", square=True, linewidth=0.1,annot=True)
# Out:
# <Axes: >
