# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\mohan rao papolu\OneDrive\chinni\Datasets\gym.csv")

# %%
data.head(45)
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# 5       Sarah Thomas   56        74 kg        Squat                 264
# 6        Emily Davis   40        83 kg     Deadlift                 132
# 7     Jessica Wilson   25       120 kg  Bench Press                 178
# 8    Michael Johnson   55        93 kg        Squat                 265
# 9        Chris Brown   20        66 kg  Bench Press                 239
# 10      Laura Taylor   31        52 kg     Deadlift                 328
# 11        Daniel Lee   38        52 kg     Deadlift                 347
# ...

# %%
data.head()
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221

# %%
data.tail()
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
data.shape
# Out:
# (3000, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
data.describe()
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [3000 rows x 5 columns]>

# %%
data.isna().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data1=data
data1.drop_duplicates(inplace=True)

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data.groupby(by='Age').count()
# Out:
#      Lifter Name  Weight Class  Lift Type  Amount Lifted (kg)
# Age
# 18            78            78         78                  78
# 19            63            63         63                  63
# 20            60            60         60                  60
# 21            72            72         72                  72
# 22            62            62         62                  62
# 23            68            68         68                  68
# 24            62            62         62                  62
# 25            66            66         66                  66
# 26            67            67         67                  67
# 27            69            69         69                  69
# 28            49            49         49                  49
# 29            67            67         67                  67
# 30            59            59         59                  59
# 31            65            65         65                  65
# ...

# %%
data[['Lifter Name','Age','Weight Class','Lift Type']]
# Out:
#          Lifter Name  Age Weight Class    Lift Type
# 0     Jessica Wilson   46        59 kg  Bench Press
# 1           John Doe   60        83 kg  Bench Press
# 2        Emily Davis   41       105 kg  Bench Press
# 3        Emily Davis   33        66 kg        Squat
# 4       Laura Taylor   56        74 kg     Deadlift
# ...              ...  ...          ...          ...
# 2995        John Doe   46        74 kg  Bench Press
# 2996      Daniel Lee   39         Open     Deadlift
# 2997    Sarah Thomas   62         Open        Squat
# 2998     Chris Brown   32        93 kg  Bench Press
# 2999      Daniel Lee   22        83 kg     Deadlift
#
# [3000 rows x 4 columns]

# %%
data[data.index.isin(range(9,45))]
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 9        Chris Brown   20        66 kg  Bench Press                 239
# 10      Laura Taylor   31        52 kg     Deadlift                 328
# 11        Daniel Lee   38        52 kg     Deadlift                 347
# 12  Matthew Anderson   64        74 kg  Bench Press                 398
# 13  Matthew Anderson   47       120 kg  Bench Press                 396
# 14        Jane Smith   50        74 kg  Bench Press                 111
# 15        Daniel Lee   37        59 kg     Deadlift                 133
# 16      Laura Taylor   62        74 kg     Deadlift                 396
# 17      Laura Taylor   62       105 kg     Deadlift                 273
# 18  Matthew Anderson   40       120 kg  Bench Press                 120
# 19        Jane Smith   40        83 kg     Deadlift                 245
# 20    Jessica Wilson   62        66 kg        Squat                 107
# ...

# %%
dt1=data['Lift Type'].value_counts()
print(dt1)
# Out:
# Lift Type
# Deadlift       1024
# Bench Press    1011
# Squat           964
# Name: count, dtype: int64

# %%
data1 = data.groupby('Lifter Name')['Amount Lifted (kg)'].sum()
print(data1)
# Out:
# Lifter Name
# Chris Brown         77165
# Daniel Lee          74776
# Emily Davis         84808
# Jane Smith          75441
# Jessica Wilson      72666
# John Doe            73317
# Laura Taylor        73925
# Matthew Anderson    73541
# Michael Johnson     71731
# Sarah Thomas        73512
# Name: Amount Lifted (kg), dtype: int64

# %%
dt=data['Amount Lifted (kg)'].value_counts()
print(dt)
# Out:
# Amount Lifted (kg)
# 276    22
# 138    18
# 223    17
# 244    17
# 100    17
#        ..
# 301     4
# 382     3
# 160     3
# 108     3
# 105     3
# Name: count, Length: 300, dtype: int64

# %%
x=data['Amount Lifted (kg)'].max()
print(x)
y=data['Amount Lifted (kg)'].min()
print(y)
# Out:
# 399
# 100

# %%
data = data.sort_values(by='Amount Lifted (kg)',ascending=False).head()
data
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2742  Chris Brown   39       120 kg     Deadlift                 399
# 2976  Emily Davis   48         Open  Bench Press                 399
# 2130   Jane Smith   28        93 kg        Squat                 399
# 2140   Jane Smith   57        74 kg  Bench Press                 399
# 2699  Emily Davis   53        74 kg        Squat                 399

# %%
x=data['Weight Class'].max()
print(x)
y=data['Weight Class'].min()
print(y)
# Out:
# Open
# 120 kg

# %%
data[data.index.isin(range(9,45))]
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 9        Chris Brown   20        66 kg  Bench Press                 239
# 10      Laura Taylor   31        52 kg     Deadlift                 328
# 11        Daniel Lee   38        52 kg     Deadlift                 347
# 12  Matthew Anderson   64        74 kg  Bench Press                 398
# 13  Matthew Anderson   47       120 kg  Bench Press                 396
# 14        Jane Smith   50        74 kg  Bench Press                 111
# 15        Daniel Lee   37        59 kg     Deadlift                 133
# 16      Laura Taylor   62        74 kg     Deadlift                 396
# 17      Laura Taylor   62       105 kg     Deadlift                 273
# 18  Matthew Anderson   40       120 kg  Bench Press                 120
# 19        Jane Smith   40        83 kg     Deadlift                 245
# 20    Jessica Wilson   62        66 kg        Squat                 107
# ...

# %%
k=data['Amount Lifted (kg)'].max()
print(k)
s=data['Amount Lifted (kg)'].min()
print(s)
# Out:
# 399
# 100

# %%
Dead_lift = data[data['Lift Type'] == 'Deadlift']
print(Dead_lift)
# Out:
#        Lifter Name  Age Weight Class Lift Type  Amount Lifted (kg)
# 4     Laura Taylor   56        74 kg  Deadlift                 221
# 6      Emily Davis   40        83 kg  Deadlift                 132
# 10    Laura Taylor   31        52 kg  Deadlift                 328
# 11      Daniel Lee   38        52 kg  Deadlift                 347
# 15      Daniel Lee   37        59 kg  Deadlift                 133
# ...            ...  ...          ...       ...                 ...
# 2989   Chris Brown   56        52 kg  Deadlift                 182
# 2990  Laura Taylor   23         Open  Deadlift                 287
# 2991      John Doe   64        93 kg  Deadlift                 263
# 2996    Daniel Lee   39         Open  Deadlift                 244
# 2999    Daniel Lee   22        83 kg  Deadlift                 280
#
# [1025 rows x 5 columns]

# %%
k = data[data['Age']>50]
print(k)
# Out:
#            Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1             John Doe   60        83 kg  Bench Press                 179
# 4         Laura Taylor   56        74 kg     Deadlift                 221
# 5         Sarah Thomas   56        74 kg        Squat                 264
# 8      Michael Johnson   55        93 kg        Squat                 265
# 12    Matthew Anderson   64        74 kg  Bench Press                 398
# ...                ...  ...          ...          ...                 ...
# 2989       Chris Brown   56        52 kg     Deadlift                 182
# 2991          John Doe   64        93 kg     Deadlift                 263
# 2992          John Doe   51        52 kg  Bench Press                 170
# 2994      Sarah Thomas   62       105 kg  Bench Press                 191
# 2997      Sarah Thomas   62         Open        Squat                 148
#
# [917 rows x 5 columns]

# %%
sns.histplot(data["Weight Class"])
# Out:
# <Axes: xlabel='Weight Class', ylabel='Count'>
